# %% [markdown]
# # Aula 30/02/2025

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
base = pd.read_csv("https://raw.githubusercontent.com/andfranca/proadi-sus-ciencia-de-dados-ia/refs/heads/main/bases/banco-laboratorio.csv")

# %%
base
# Out:
#       IDCOLABORADOR  IDADE INSATISTFEITO STATUSCIVIL     GENERO  \
# 0                 1     41           Sim    Solteiro   Feminino
# 1                 5     33           Nao      Casado   Feminino
# 2                10     59           Nao      Casado   Feminino
# 3                15     29           Nao    Solteiro   Feminino
# 4                20     29           Nao  Divorciado   Feminino
# ...             ...    ...           ...         ...        ...
# 1465           2061     36           Nao      Casado  Masculino
# 1466           2062     39           Nao      Casado  Masculino
# 1467           2064     27           Nao      Casado  Masculino
# 1468           2065     49           Nao      Casado  Masculino
# 1469           2068     34           Nao      Casado  Masculino
#
#                 NOME      SETOR                   CARGO   CEP  NIVELEDUCACAO  \
# 0     Maria da Silva  Alimentos                 Auditor   1.0              2
# ...

# %%
base.describe()
# Out:
#        IDCOLABORADOR        IDADE          CEP  NIVELEDUCACAO   RENDAMENSAL  \
# count    1470.000000  1470.000000  1426.000000    1470.000000   1470.000000
# mean     1024.865306    36.923810     9.140252       2.912925  14313.103401
# std       602.024335     9.135373     8.065954       1.024165   7117.786044
# min         1.000000    18.000000     1.000000       1.000000   2094.000000
# 25%       491.250000    30.000000     2.000000       2.000000   8047.000000
# 50%      1020.500000    36.000000     7.000000       3.000000  14235.500000
# 75%      1555.750000    43.000000    14.000000       4.000000  20461.500000
# max      2068.000000    60.000000    29.000000       5.000000  26999.000000
#
#        ANONAEMPRESA  ANOSMESMAPOSICAO  ANOSDESDEULTIMAPROMOCAO
# count   1470.000000       1470.000000              1470.000000
# mean       7.008163          4.229252                 2.187755
# std        6.126525          3.623137                 3.222430
# ...

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   IDCOLABORADOR            1470 non-null   int64
#  1   IDADE                    1470 non-null   int64
#  2   INSATISTFEITO            1470 non-null   object
#  3   STATUSCIVIL              1470 non-null   object
#  4   GENERO                   1470 non-null   object
#  5   NOME                     1470 non-null   object
#  6   SETOR                    1470 non-null   object
#  7   CARGO                    1470 non-null   object
#  8   CEP                      1426 non-null   float64
#  9   NIVELEDUCACAO            1470 non-null   int64
#  10  FORMACAO                 1470 non-null   object
#  11  RENDAMENSAL              1470 non-null   int64
#  12  DESCONTOULTIMAFATURA     1470 non-null   object
#  13  ANONAEMPRESA             1470 non-null   int64
# ...

# %%
base.isna().sum()
# Out:
# IDCOLABORADOR               0
# IDADE                       0
# INSATISTFEITO               0
# STATUSCIVIL                 0
# GENERO                      0
# NOME                        0
# SETOR                       0
# CARGO                       0
# CEP                        44
# NIVELEDUCACAO               0
# FORMACAO                    0
# RENDAMENSAL                 0
# DESCONTOULTIMAFATURA        0
# ANONAEMPRESA                0
# ANOSMESMAPOSICAO            0
# ANOSDESDEULTIMAPROMOCAO     0
# dtype: int64

# %%
base[['IDADE','INSATISTFEITO']]
# Out:
#       IDADE INSATISTFEITO
# 0        41           Sim
# 1        33           Nao
# 2        59           Nao
# 3        29           Nao
# 4        29           Nao
# ...     ...           ...
# 1465     36           Nao
# 1466     39           Nao
# 1467     27           Nao
# 1468     49           Nao
# 1469     34           Nao
#
# [1470 rows x 2 columns]

# %%
base[base['IDADE']>=30]
# Out:
#       IDCOLABORADOR  IDADE INSATISTFEITO STATUSCIVIL     GENERO  \
# 0                 1     41           Sim    Solteiro   Feminino
# 1                 5     33           Nao      Casado   Feminino
# 2                10     59           Nao      Casado   Feminino
# 5                23     53           Nao      Casado   Feminino
# 7                28     34           Nao    Solteiro   Feminino
# ...             ...    ...           ...         ...        ...
# 1464           2057     31           Nao    Solteiro  Masculino
# 1465           2061     36           Nao      Casado  Masculino
# 1466           2062     39           Nao      Casado  Masculino
# 1468           2065     49           Nao      Casado  Masculino
# 1469           2068     34           Nao      Casado  Masculino
#
#                   NOME      SETOR                   CARGO   CEP  \
# 0       Maria da Silva  Alimentos                 Auditor   1.0
# 1         Ana Oliveira      Saude             Pesquisador   3.0
# ...

# %%
base[
    (base['IDADE']>=30)&
    (base['STATUSCIVIL']=='Casado')
    ]
# Out:
#       IDCOLABORADOR  IDADE INSATISTFEITO STATUSCIVIL     GENERO  \
# 1                 5     33           Nao      Casado   Feminino
# 2                10     59           Nao      Casado   Feminino
# 5                23     53           Nao      Casado   Feminino
# 10               36     44           Nao      Casado   Feminino
# 13               49     35           Nao      Casado   Feminino
# ...             ...    ...           ...         ...        ...
# 1461           2049     35           Nao      Casado  Masculino
# 1465           2061     36           Nao      Casado  Masculino
# 1466           2062     39           Nao      Casado  Masculino
# 1468           2065     49           Nao      Casado  Masculino
# 1469           2068     34           Nao      Casado  Masculino
#
#                   NOME      SETOR                   CARGO   CEP  \
# 1         Ana Oliveira      Saude             Pesquisador   3.0
# 2       Juliana Santos      Saude  Tecnico de Laboratorio   3.0
# ...

# %% [markdown]
# #Aplicando filtros

# %%
base[
    (base['IDADE']>=30)&
    (base['STATUSCIVIL']=='Casado')&
    (base['INSATISTFEITO']=="Sim")
    ]
# Out:
#       IDCOLABORADOR  IDADE INSATISTFEITO STATUSCIVIL     GENERO  \
# 18               58     41           Sim      Casado   Feminino
# 46              161     56           Sim      Casado   Feminino
# 48              165     58           Sim      Casado   Feminino
# 52              175     31           Sim      Casado   Feminino
# 96              328     33           Sim      Casado   Feminino
# 126             445     39           Sim      Casado   Feminino
# 203             684     45           Sim      Casado   Feminino
# 247             840     49           Sim      Casado   Feminino
# 294            1004     30           Sim      Casado   Feminino
# 306            1033     37           Sim      Casado   Feminino
# 308            1038     52           Sim      Casado   Feminino
# 380            1295     44           Sim      Casado   Feminino
# 399            1360     58           Sim      Casado   Feminino
# 408            1380     35           Sim      Casado   Feminino
# ...

# %%
# Opção 1 - cria o objeto base filtrada
base_filtrada= base[
    (base['IDADE']>=30)&
    (base['STATUSCIVIL']=='Casado')&
    (base['INSATISTFEITO']=="Sim")
    ]

# %%
#Opção 2 - Ja cria o subseting diretamente das colunas que preciso
base_filtrada_sub= base[
    (base['IDADE']>=30)&
    (base['STATUSCIVIL']=='Casado')&
    (base['INSATISTFEITO']=="Sim")
    ][['IDADE','STATUSCIVIL']]

# %%
base_filtrada
# Out:
#       IDCOLABORADOR  IDADE INSATISTFEITO STATUSCIVIL     GENERO  \
# 18               58     41           Sim      Casado   Feminino
# 46              161     56           Sim      Casado   Feminino
# 48              165     58           Sim      Casado   Feminino
# 52              175     31           Sim      Casado   Feminino
# 96              328     33           Sim      Casado   Feminino
# 126             445     39           Sim      Casado   Feminino
# 203             684     45           Sim      Casado   Feminino
# 247             840     49           Sim      Casado   Feminino
# 294            1004     30           Sim      Casado   Feminino
# 306            1033     37           Sim      Casado   Feminino
# 308            1038     52           Sim      Casado   Feminino
# 380            1295     44           Sim      Casado   Feminino
# 399            1360     58           Sim      Casado   Feminino
# 408            1380     35           Sim      Casado   Feminino
# ...

# %%
base_filtrada_sub
# Out:
#       IDADE STATUSCIVIL
# 18       41      Casado
# 46       56      Casado
# 48       58      Casado
# 52       31      Casado
# 96       33      Casado
# 126      39      Casado
# 203      45      Casado
# 247      49      Casado
# 294      30      Casado
# 306      37      Casado
# 308      52      Casado
# 380      44      Casado
# 399      58      Casado
# 408      35      Casado
# 434      34      Casado
# 454      53      Casado
# 494      48      Casado
# 523      46      Casado
# 539      46      Casado
# 609      39      Casado
# 611      50      Casado
# 629      36      Casado
# 665      31      Casado
# 700      35      Casado
# 710      38      Casado
# 714      32      Casado
# 727      33      Casado
# 753      47      Casado
# 784      52      Casado
# 812      40      Casado
# 845      33      Casado
# 849      31      Casado
# 867      32      Casado
# 875      30      Casado
# 905      50      Casado
# 930      55      Casado
# 984      39      Casado
# ...

# %% [markdown]
# Após criar a base filtrada podemos deletar a base original para reduzir o tamabho do arquivo - "del base"

# %% [markdown]
# Agora vamos exportar para csv

# %%
base_filtrada.to_csv('base_filtrada.csv',index=False, decimal=',')

# %% [markdown]
# Incluindo colunas

# %%
base_filtrada['Coluna_nova'] = base_filtrada['IDADE'] + 10
# Out:
# C:\Users\jonat\AppData\Local\Temp\ipykernel_14512\347492228.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_filtrada['Coluna_nova'] = base_filtrada['IDADE'] + 10

# %%
base_filtrada
# Out:
#       IDCOLABORADOR  IDADE INSATISTFEITO STATUSCIVIL     GENERO  \
# 18               58     41           Sim      Casado   Feminino
# 46              161     56           Sim      Casado   Feminino
# 48              165     58           Sim      Casado   Feminino
# 52              175     31           Sim      Casado   Feminino
# 96              328     33           Sim      Casado   Feminino
# 126             445     39           Sim      Casado   Feminino
# 203             684     45           Sim      Casado   Feminino
# 247             840     49           Sim      Casado   Feminino
# 294            1004     30           Sim      Casado   Feminino
# 306            1033     37           Sim      Casado   Feminino
# 308            1038     52           Sim      Casado   Feminino
# 380            1295     44           Sim      Casado   Feminino
# 399            1360     58           Sim      Casado   Feminino
# 408            1380     35           Sim      Casado   Feminino
# ...

# %% [markdown]
# # Aula do dia 31/01/2025

# %%
energia = pd.read_csv(r"C:\Users\jonat\OneDrive\Documentos\GitHub\Curso-CDIA\previsao_energia_solar (1).csv", decimal=',')

# %%
energia
# Out:
#        Localizacao      Data  Mes  Hora  Estacao   Umidade  Temperatura  \
# 0                0  20171203   12    11        0  81.71997     12.86919
# 1                0  20171203   12    13        0  96.64917      9.66415
# 2                0  20171203   12    13        0  93.61572     15.44983
# 3                0  20171204   12    12        0  77.21558     10.36659
# 4                0  20171204   12    14        0  54.80347     16.85471
# ...            ...       ...  ...   ...      ...       ...          ...
# 21040           11  20180928    9    15        3  11.66992     43.22510
# 21041           11  20180929    9    13        3  18.22510     28.98247
# 21042           11  20180929    9    14        3  15.52124     33.49167
# 21043           11  20180929    9    15        3   6.63452     51.62163
# 21044           11  20181001   10    14        3  22.58301     32.83958
#
#         Geracao  Vento  Visibilidade  Pressao  Cloud.Ceiling
# ...

# %%
energia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21045 entries, 0 to 21044
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Localizacao    21045 non-null  int64
#  1   Data           21045 non-null  int64
#  2   Mes            21045 non-null  int64
#  3   Hora           21045 non-null  int64
#  4   Estacao        21045 non-null  int64
#  5   Umidade        21045 non-null  float64
#  6   Temperatura    21045 non-null  float64
#  7   Geracao        21045 non-null  float64
#  8   Vento          21045 non-null  int64
#  9   Visibilidade   21045 non-null  float64
#  10  Pressao        21045 non-null  float64
#  11  Cloud.Ceiling  21045 non-null  int64
# dtypes: float64(5), int64(7)
# memory usage: 1.9 MB

# %%
energia.describe()
# Out:
#         Localizacao          Data           Mes          Hora       Estacao  \
# count  21045.000000  2.104500e+04  21045.000000  21045.000000  21045.000000
# mean       6.091518  2.017720e+07      6.565883     12.627845      1.636731
# std        3.600643  4.579585e+03      2.983958      1.672952      0.997188
# min        0.000000  2.017052e+07      1.000000     10.000000      0.000000
# 25%        3.000000  2.017111e+07      4.000000     11.000000      1.000000
# 50%        6.000000  2.018032e+07      7.000000     13.000000      2.000000
# 75%       10.000000  2.018062e+07      9.000000     14.000000      2.000000
# max       11.000000  2.018100e+07     12.000000     15.000000      3.000000
#
#               Vento  Cloud.Ceiling
# count  21045.000000   21045.000000
# mean      10.318318     515.966785
# std        6.385030     301.903379
# min        0.000000       0.000000
# 25%        6.000000     140.000000
# 50%        9.000000     722.000000
# ...

# %% [markdown]
# ## Iniciando o SKLEARN para fazer o train test split

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Cirando a as varáveis X e Y - sendo X a a base sem a variável alvo e o Y apenas a variável alvo

# %%
X = energia.drop('Geracao', axis=1)
y = energia['Geracao']

# %%
X
# Out:
#        Localizacao      Data  Mes  Hora  Estacao   Umidade  Temperatura  \
# 0                0  20171203   12    11        0  81.71997     12.86919
# 1                0  20171203   12    13        0  96.64917      9.66415
# 2                0  20171203   12    13        0  93.61572     15.44983
# 3                0  20171204   12    12        0  77.21558     10.36659
# 4                0  20171204   12    14        0  54.80347     16.85471
# ...            ...       ...  ...   ...      ...       ...          ...
# 21040           11  20180928    9    15        3  11.66992     43.22510
# 21041           11  20180929    9    13        3  18.22510     28.98247
# 21042           11  20180929    9    14        3  15.52124     33.49167
# 21043           11  20180929    9    15        3   6.63452     51.62163
# 21044           11  20181001   10    14        3  22.58301     32.83958
#
#        Vento  Visibilidade  Pressao  Cloud.Ceiling
# 0          5          10.0   1010.6            722
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
[X_train.shape, X_test.shape, y_train.shape, y_test.shape]
# Out:
# [(14731, 11), (6314, 11), (14731,), (6314,)]

# %% [markdown]
# ### Agora vamos importar o modelo que treinaremos com os dados

# %%
from sklearn.linear_model import LinearRegression

# %%
modelo = LinearRegression()

# %%
modelo.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = modelo.predict(X_test)

# %%
modelo.score(X_test, y_test)
# Out:
# 0.4650574337580161

# %% [markdown]
# ### Aqui ele da o coeficiente de correlação de cada uam das 11 variáveis independentes

# %%
modelo.coef_
# Out:
# array([-1.15226097e-01, -6.88007778e-05, -4.87036591e-01, -9.25196127e-02,
#         3.85676781e-01, -3.39978232e-02,  2.82905979e-01,  1.27104909e-01,
#         1.36818858e-01,  1.30985478e-02,  4.93658195e-03])

# %% [markdown]
# ### Incluir as previsões e valores reais na tabela X_test para verificar a acuracia

# %%
X_test['y_pred'] = y_pred
X_test['y_test'] = y_test

# %%
X_test
# Out:
#        Localizacao      Data  Mes  Hora  Estacao   Umidade  Temperatura  \
# 20644           11  20180727    7    11        2  35.69336     34.77318
# 20802           11  20180816    8    15        2  10.96802     58.63594
# 6836             4  20171115   11    13        3  71.70410     25.25124
# 5865             3  20171122   11    13        3  36.25488     41.87813
# 7628             4  20180531    5    14        1  53.44849     31.05705
# ...            ...       ...  ...   ...      ...       ...          ...
# 2359             1  20180817    8    10        2  84.39941     26.43456
# 673              0  20180711    7    12        2  17.24243     43.85704
# 12659            8  20180625    6    15        2  99.98779     23.30254
# 13138            9  20170630    6    15        2  22.19238     28.33542
# 15348            9  20180724    7    11        2  22.33276     46.36719
#
#        Vento  Visibilidade  Pressao  Cloud.Ceiling     y_pred    y_test
# ...
